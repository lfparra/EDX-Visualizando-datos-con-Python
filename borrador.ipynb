# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import pandas as pd

# %%
plt.plot(5, 5, 'o')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.ylabel('Y')
plt.xlabel('X')
plt.title('Plotting Example')
# Out:
# Text(0.5, 1.0, 'Plotting Example')

# %%
india_china_df=pd.DataFrame({'año' : [1980, 1981, 1982, 1983, 1984], 
                             'India' : [8880, 8670, 8147, 7338, 5704], 
                             'China' : [5123, 6682, 3308, 1863, 1527]})

india_china_df
# Out:
#     año  India  China
# 0  1980   8880   5123
# 1  1981   8670   6682
# 2  1982   8147   3308
# 3  1983   7338   1863
# 4  1984   5704   1527

# %%
india_china_df = india_china_df.set_index("año")
india_china_df
# Out:
#       India  China
# año
# 1980   8880   5123
# 1981   8670   6682
# 1982   8147   3308
# 1983   7338   1863
# 1984   5704   1527

# %%
india_china_df.plot(kind='line')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='año'>

# %%
india_china_df['India'].plot(kind='hist')
# Out:
# <AxesSubplot:xlabel='año', ylabel='Frequency'>
