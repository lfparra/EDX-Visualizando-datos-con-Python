# %%
import numpy as np
import pandas as pd
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
# !pip install xlrd
print('xlrd installed!')
# Out:
# ...
# xlrd installed!

# %%
df_canada = pd.read_excel(
    'C:/Users/leopa/Documents/Programacion/Jupyter Notebook/EDX/Visualizando datos con Python/Canada.xlsx',
    sheet_name = 'Canada by Citizenship',
    skiprows = range(20),
    skipfooter = 2)

df_canada
# Out:
#            Type    Coverage          OdName  AREA AreaName   REG  \
# 0    Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1    Immigrants  Foreigners         Albania   908   Europe   925
# 2    Immigrants  Foreigners         Algeria   903   Africa   912
# 3    Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4    Immigrants  Foreigners         Andorra   908   Europe   925
# ..          ...         ...             ...   ...      ...   ...
# 190  Immigrants  Foreigners        Viet Nam   935     Asia   920
# 191  Immigrants  Foreigners  Western Sahara   903   Africa   912
# 192  Immigrants  Foreigners           Yemen   935     Asia   922
# 193  Immigrants  Foreigners          Zambia   903   Africa   910
# 194  Immigrants  Foreigners        Zimbabwe   903   Africa   910
#
#                 RegName  DEV             DevName  1980  ...  2004  2005  2006  \
# 0         Southern Asia  902  Developing regions    16  ...  2978  3436  3009
# ...

# %%
df_canada.dtypes
# Out:
# Type        object
# Coverage    object
# OdName      object
# AREA         int64
# AreaName    object
# REG          int64
# RegName     object
# DEV          int64
# DevName     object
# 1980         int64
# 1981         int64
# 1982         int64
# 1983         int64
# 1984         int64
# 1985         int64
# 1986         int64
# 1987         int64
# 1988         int64
# 1989         int64
# 1990         int64
# 1991         int64
# 1992         int64
# 1993         int64
# 1994         int64
# 1995         int64
# 1996         int64
# 1997         int64
# 1998         int64
# 1999         int64
# 2000         int64
# 2001         int64
# 2002         int64
# 2003         int64
# 2004         int64
# 2005         int64
# 2006         int64
# 2007         int64
# 2008         int64
# 2009         int64
# 2010         int64
# 2011         int64
# 2012         int64
# 2013         int64
# dtype: object

# %%
df_canada.rename(columns={'OdName':'Country'}, inplace = True)

# %%
df_canada.dtypes
# Out:
# Type        object
# Coverage    object
# Country     object
# AREA         int64
# AreaName    object
# REG          int64
# RegName     object
# DEV          int64
# DevName     object
# 1980         int64
# 1981         int64
# 1982         int64
# 1983         int64
# 1984         int64
# 1985         int64
# 1986         int64
# 1987         int64
# 1988         int64
# 1989         int64
# 1990         int64
# 1991         int64
# 1992         int64
# 1993         int64
# 1994         int64
# 1995         int64
# 1996         int64
# 1997         int64
# 1998         int64
# 1999         int64
# 2000         int64
# 2001         int64
# 2002         int64
# 2003         int64
# 2004         int64
# 2005         int64
# 2006         int64
# 2007         int64
# 2008         int64
# 2009         int64
# 2010         int64
# 2011         int64
# 2012         int64
# 2013         int64
# dtype: object

# %%
df_canada = df_canada.set_index("Country")
df_canada
# Out:
#                       Type    Coverage  AREA AreaName   REG  \
# Country
# Afghanistan     Immigrants  Foreigners   935     Asia  5501
# Albania         Immigrants  Foreigners   908   Europe   925
# Algeria         Immigrants  Foreigners   903   Africa   912
# American Samoa  Immigrants  Foreigners   909  Oceania   957
# Andorra         Immigrants  Foreigners   908   Europe   925
# ...                    ...         ...   ...      ...   ...
# Viet Nam        Immigrants  Foreigners   935     Asia   920
# Western Sahara  Immigrants  Foreigners   903   Africa   912
# Yemen           Immigrants  Foreigners   935     Asia   922
# Zambia          Immigrants  Foreigners   903   Africa   910
# Zimbabwe        Immigrants  Foreigners   903   Africa   910
#
#                            RegName  DEV             DevName  1980  1981  ...  \
# Country                                                                  ...
# Afghanistan          Southern Asia  902  Developing regions    16    39  ...
# ...

# %%
df_canada['Total'] = df_canada.iloc[:, 8:42].sum(axis=1)
df_canada
# Out:
#                       Type    Coverage  AREA AreaName   REG  \
# Country
# Afghanistan     Immigrants  Foreigners   935     Asia  5501
# Albania         Immigrants  Foreigners   908   Europe   925
# Algeria         Immigrants  Foreigners   903   Africa   912
# American Samoa  Immigrants  Foreigners   909  Oceania   957
# Andorra         Immigrants  Foreigners   908   Europe   925
# ...                    ...         ...   ...      ...   ...
# Viet Nam        Immigrants  Foreigners   935     Asia   920
# Western Sahara  Immigrants  Foreigners   903   Africa   912
# Yemen           Immigrants  Foreigners   935     Asia   922
# Zambia          Immigrants  Foreigners   903   Africa   910
# Zimbabwe        Immigrants  Foreigners   903   Africa   910
#
#                            RegName  DEV             DevName  1980  1981  ...  \
# Country                                                                  ...
# Afghanistan          Southern Asia  902  Developing regions    16    39  ...
# ...

# %%
df_canada.dtypes
# Out:
# Type        object
# Coverage    object
# AREA         int64
# AreaName    object
# REG          int64
# RegName     object
# DEV          int64
# DevName     object
# 1980         int64
# 1981         int64
# 1982         int64
# 1983         int64
# 1984         int64
# 1985         int64
# 1986         int64
# 1987         int64
# 1988         int64
# 1989         int64
# 1990         int64
# 1991         int64
# 1992         int64
# 1993         int64
# 1994         int64
# 1995         int64
# 1996         int64
# 1997         int64
# 1998         int64
# 1999         int64
# 2000         int64
# 2001         int64
# 2002         int64
# 2003         int64
# 2004         int64
# 2005         int64
# 2006         int64
# 2007         int64
# 2008         int64
# 2009         int64
# 2010         int64
# 2011         int64
# 2012         int64
# 2013         int64
# Total        int64
# dtype: object

# %%
years = list(map(int, range(1980, 2014)))


df_canada.loc["Haiti", years].plot(kind = 'line')

plt.title('Inmigration from Haiti')
plt.ylabel('Number of inmigrants')
plt.xlabel('years')
# Out:
# <img src="data:," width="0">
# Text(0.5, 0, 'years')

# %%
df_canada.sort_values(['Total'], ascending = False, axis = 0, inplace = True)
df_canada
# Out:
#                                                           Type    Coverage  \
# Country
# India                                               Immigrants  Foreigners
# China                                               Immigrants  Foreigners
# United Kingdom of Great Britain and Northern Ir...  Immigrants  Foreigners
# Philippines                                         Immigrants  Foreigners
# Pakistan                                            Immigrants  Foreigners
# ...                                                        ...         ...
# San Marino                                          Immigrants  Foreigners
# New Caledonia                                       Immigrants  Foreigners
# Marshall Islands                                    Immigrants  Foreigners
# Western Sahara                                      Immigrants  Foreigners
# Palau                                               Immigrants  Foreigners
#
# ...

# %%
df_top5 = df_canada.head(5)
df_top5 = df_top5[years].transpose()
df_top5

# %%
df_top5.loc[years].plot(kind = 'area')

plt.title('Inmigration trend of Top5 Countries')
plt.ylabel('Number of inmigrants')
plt.xlabel('Years')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 0, 'Years')

# %%
count, bin_edges = np.histogram(df_canada[2013])
df_canada[2013].plot(kind = 'hist', xticks = bin_edges)

plt.title('Histogram from 195 countries in 2013')
plt.ylabel('Number of Countries')
plt.xlabel('Number of Inmigrants')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 0, 'Number of Inmigrants')
